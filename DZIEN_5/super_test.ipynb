# %%
print("to jest nowy notebook")
# Out:
# to jest nowy notebook

# %%
import numpy as np
import pandas as pd

# %%
a = 564
n = 55

# %%
a*n
# Out:
# 31020

# %%
s = "ładna pogoda"

# %%
s
# Out:
# 'ładna pogoda'

# %%
price = "22"

# %%
lsztuk = 10

# %%
float(price)*int(lsztuk)
# Out:
# 220.0
